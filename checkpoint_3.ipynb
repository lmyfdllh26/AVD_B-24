# %% [markdown]
# **Checkpoint 3**

# %% [markdown]
# sumber : https://www.kaggle.com/datasets/anasfikrihanif/indonesian-food-and-drink-nutrition-dataset

# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('/content/archive.zip')
df
# Out:
#         id  calories  proteins   fat  carbohydrate                name  \
# 0        1     280.0       9.2  28.4           0.0                Abon
# 1        2     513.0      23.7  37.0          21.3        Abon haruwan
# 2        3       0.0       0.0   0.2           0.0           Agar-agar
# 3        4      45.0       1.1   0.4          10.8  Akar tonjong segar
# 4        5      37.0       4.4   0.5           3.8       Aletoge segar
# ...    ...       ...       ...   ...           ...                 ...
# 1341  1342      42.0       1.2   0.6           9.3        Wortel Segar
# 1342  1343      37.0       1.0   0.6           8.3        Wortel kukus
# 1343  1344      28.0       0.7   0.5           6.3        Wortel rebus
# 1344  1345     254.0       3.0   1.1          58.1              Yangko
# 1345  1346      52.0       3.3   2.5           4.0             Yoghurt
#
#                                                   image
# 0     https://img-cdn.medkomtek.com/PbrY9X3ignQ8sVuj...
# ...

# %%
df.nlargest(10, "calories")
# Out:
#       id  calories  proteins    fat  carbohydrate                       name  \
# 949  950     940.0      36.0   42.0         104.0             Opak Singkong
# 837  838     902.0       0.0  100.0           0.0                 Lemak Babi
# 901  902     902.0       0.0  100.0           0.0  Minyak Hati Hiu (Eulamia)
# 902  903     902.0       0.0  100.0           0.0                Minyak Ikan
# 903  904     902.0       0.0  100.0           0.0        Minyak Kacang Tanah
# 906  907     902.0       0.0  100.0           0.0        Minyak Kelapa Sawit
# 907  908     902.0       0.0  100.0           0.0               Minyak Wijen
# 908  909     884.0       0.0  100.0           0.0              Minyak Zaitun
# 904  905     883.0       0.0   99.9           0.0             Minyak kedelai
# 905  906     870.0       1.0   98.0           0.0              Minyak Kelapa
#
#                                                  image
# 949  https://cf.shopee.co.id/file/f10cd2d5ad4812daf...
# ...

# %% [markdown]
# **10 Makanan dengan kalori tertinggi**

# %%
plt.figure(figsize=(6, 5))
plt.barh(df.nlargest(10, "calories")["name"], df.nlargest(10, "calories")["calories"], color='pink')
plt.title('10 makanan kalori tertinggi')
plt.xlabel('kalori')
plt.ylabel('makanan')
plt.xticks(rotation=45)
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# **10 Makanan dengan kalori terendah**

# %%
df.nsmallest(10,"calories")
# Out:
#         id  calories  proteins  fat  carbohydrate                      name  \
# 2        3       0.0       0.0  0.2           0.0                 Agar-agar
# 1032  1033       4.0       0.0  0.0           0.9         Rambutan sinyonya
# 761    762       9.0       0.5  0.1           1.9      Ketimun madura segar
# 933    934       9.0       2.1  6.0           7.1                 Olah-olah
# 1105  1106       9.0       1.0  0.1           1.7  Sawi putih / pecai segar
# 1030  1031      11.0       0.0  0.0           2.7             Rambutan Aceh
# 220    221      12.0       0.1  0.1           5.0                      Cuka
# 760    761      12.0       0.7  0.1           2.7                   Ketimun
# 1148  1149      12.0       0.5  0.1           2.0                  Sop Kool
# 66      67      13.0       0.4  0.2           3.0                    Baligo
#
#                                                   image
# 2     https://res.cloudinary.com/dk0z4ums3/image/upl...
# ...

# %%
plt.figure(figsize=(6, 5))
plt.barh(df.nsmallest(10, "calories")["name"], df.nsmallest(10, "calories")["calories"], color='coral')
plt.title('10 makanan kalori terendah')
plt.xlabel('kalori')
plt.ylabel('makanan')
plt.xticks(rotation=45)
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# **Korelasi kalori dan lemak**

# %%
# Scatter Plot (Matplotlib): Durasi vs. Jumlah Buku Dipinjam
plt.figure(figsize=(8, 5))
plt.scatter(df['calories'], df['fat'], c='red', alpha=0.5)
plt.title('kalori vs lemak')
plt.xlabel('kalori')
plt.ylabel('lemak')
plt.show()

# %%
correlation = df["calories"].corr(df["fat"])
print(f"Korelasi antara kalori dan lemak: {correlation:.2f}")
# Out:
# Korelasi antara kalori dan lemak: 0.74

# %% [markdown]
# Korelasi 0.74 menunjukkan bahwa Makanan tinggi lemak cenderung tinggi kalori, tetapi makanan tinggi karbohidrat atau protein juga bisa memiliki kalori tinggi.

# %% [markdown]
# **Makanan Sehat vs. Kurang Sehat**

# %%
def kategori_makanan(row):
    if row["calories"] < 300 and row["fat"] < 10 and row["carbohydrate"] < 50 and row["proteins"] > 5:
        return "Sehat"
    else:
        return "Kurang Sehat"

df["Kategori"] = df.apply(kategori_makanan, axis=1)
print(df["Kategori"].value_counts())  # Lihat jumlah makanan sehat & kurang sehat
# Out:
# Kategori
# Kurang Sehat    1038
# Sehat            308
# Name: count, dtype: int64

# %%
sehat = df[df["Kategori"] == "Sehat"]
print(sehat[["name", "calories", "fat", "carbohydrate", "proteins"]])
# Out:
#                            name  calories  fat  carbohydrate  proteins
# 32       Ayam dideh/darah segar      75.0  1.9           0.7      13.8
# 40    Ayam goreng pasundan dada     246.0  9.0           0.7      37.9
# 43    Ayam goreng sukabumi dada     244.0  9.2           1.0      36.7
# 48                        Babat     113.0  4.2           0.0      17.6
# 51            Babi ginjal segar     110.0  4.6           0.8      16.3
# ...                         ...       ...  ...           ...       ...
# 1323               Udang kering     295.0  2.3           1.8      62.4
# 1324        Udang kering mentah     278.0  4.1           2.2      62.6
# 1325         Udang papay mentah     273.0  3.8          12.5      47.8
# 1326                Udang segar      91.0  0.2           0.1      21.0
# 1331                  Usus Sapi     130.0  7.2           1.5      14.0
#
# [308 rows x 5 columns]

# %%
kurang_sehat = df[df["Kategori"] == "Kurang Sehat"]
print(kurang_sehat[["name", "calories", "fat", "carbohydrate", "proteins"]])
# Out:
#                     name  calories   fat  carbohydrate  proteins
# 0                   Abon     280.0  28.4           0.0       9.2
# 1           Abon haruwan     513.0  37.0          21.3      23.7
# 2              Agar-agar       0.0   0.2           0.0       0.0
# 3     Akar tonjong segar      45.0   0.4          10.8       1.1
# 4          Aletoge segar      37.0   0.5           3.8       4.4
# ...                  ...       ...   ...           ...       ...
# 1341        Wortel Segar      42.0   0.6           9.3       1.2
# 1342        Wortel kukus      37.0   0.6           8.3       1.0
# 1343        Wortel rebus      28.0   0.5           6.3       0.7
# 1344              Yangko     254.0   1.1          58.1       3.0
# 1345             Yoghurt      52.0   2.5           4.0       3.3
#
# [1038 rows x 5 columns]

# %%
df.nlargest(10, "proteins")
# Out:
#         id  calories  proteins   fat  carbohydrate  \
# 742    743     422.0      83.0   4.0           0.0
# 320    321     598.0      74.3  26.9           9.2
# 476    477     598.0      74.3  26.9           9.2
# 460    461     302.0      70.7   1.9           0.4
# 518    519     331.0      68.7   4.2           0.0
# 477    478     582.0      68.3  15.2          37.2
# 1324  1325     278.0      62.6   4.1           2.2
# 1323  1324     295.0      62.4   2.3           1.8
# 493    494     415.0      61.3  17.6           2.9
# 514    515     316.0      60.1   6.5          22.4
#
#                             name  \
# 742         Kerupuk Kulit kerbau
# 320       Dendeng mujahir goreng
# 476   Ikan Mujair dendeng goreng
# 460             Ikan kayu kering
# 518       Ikan Teri Kering tawar
# 477   Ikan Mujair dendeng mentah
# 1324         Udang kering mentah
# 1323                Udang kering
# 493        Ikan sale lais mentah
# 514           Ikan tepung mentah
#
# ...

# %%
plt.figure(figsize=(6, 6))
plt.pie(df["Kategori"].value_counts(), labels=df["Kategori"].value_counts().index, autopct='%1.1f%%', colors=['lightcoral', 'lightblue', 'lightgreen', 'gold'])
plt.title('Distribusi Tujuan Kunjungan')
plt.show()
